# %%
# here we are loading the iris data
from sklearn import svm, datasets
iris = datasets.load_iris()

# %%
# here we are making the dataframe
import pandas as pd
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['flower'] = iris.target
df['flower'] = df['flower'].apply(lambda x: iris.target_names[x])
df[:10]
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
# 6                4.6               3.4                1.4               0.3
# 7                5.0               3.4                1.5               0.2
# 8                4.4               2.9                1.4               0.2
# 9                4.9               3.1                1.5               0.1
#
#    flower
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
# 5  setosa
# 6  setosa
# 7  setosa
# 8  setosa
# 9  setosa

# %%
# splitting the datasets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3)

# %%
# here training and testing the model
# evaluating the model
model = svm.SVC(kernel='rbf',C=30,gamma='auto')
model.fit(X_train,y_train)
model.score(X_test, y_test)
# Out:
# 0.9777777777777777

# %%
# we can test the model using different parameters
from sklearn.model_selection import GridSearchCV
clf = GridSearchCV(svm.SVC(gamma='auto'),{
    'C' : [1,10,20,30],
    'kernel': ['rbf','linear']
},cv=5)
clf.fit(X_train,y_train)
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.0008141 , 0.00059981, 0.00100336, 0.00099926, 0.00102358,
#         0.00059919, 0.00079951, 0.00068326]),
#  'std_fit_time': array([4.07903953e-04, 4.89745942e-04, 9.85058322e-06, 6.97552626e-07,
#         4.42825912e-05, 4.89239511e-04, 3.99762642e-04, 5.72502663e-04]),
#  'mean_score_time': array([0.00108161, 0.00060005, 0.00060463, 0.00060058, 0.00019994,
#         0.00040002, 0.00080051, 0.00040126]),
#  'std_score_time': array([0.0001514 , 0.00048995, 0.00049378, 0.00049037, 0.00039988,
#         0.00048992, 0.00040026, 0.00049144]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 30, 30],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear',
#                     'rbf', 'linear'],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=np.str_('?'),
# ...

# %%
DF = pd.DataFrame(clf.cv_results_)
DF[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.971429
# 1        1       linear         0.952381
# 2       10          rbf         0.952381
# 3       10       linear         0.952381
# 4       20          rbf         0.952381
# 5       20       linear         0.952381
# 6       30          rbf         0.933333
# 7       30       linear         0.952381

# %%
# gere there are more parameters
dir(clf)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__sklearn_tags__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_refit_for_multimetric',
#  '_check_scorers_accept_sample_weight',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_format_results',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_params_html',
#  '_get_routed_params_for_fit',
#  '_get_scorers',
# ...

# %%
# to find the best score
clf.best_score_
# Out:
# np.float64(0.9714285714285713)

# %%
# to find the parameter of the best score
clf.best_params_
# Out:
# {'C': 1, 'kernel': 'rbf'}
